# %%
import numpy as np
import base64


# Simple model definition
class SimpleNN:
    def __init__(self, input_size=10, hidden_layers=[64, 128, 64], output_size=1):
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.output_size = output_size


model = SimpleNN()

# Generate dataset
np.random.seed(42)
dataset = np.random.randn(1000, 10)

print(f"Model: Simple Neural Network")
print(f"Dataset shape: {dataset.shape}")
# Out:
# Model: Simple Neural Network
# Dataset shape: (1000, 10)
# Audio sample generated: 8388608 bytes (8.0 MB)
# {'model': 'SimpleNN', 'layers': [10, 64, 128, 64, 1], 'activation': 'relu', 'dataset_size': 1000, 'features': 10, 'audio_data': 'iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAYAAAAfFcSJAAAADUlEQVR42mNk+M9QDwADhgGAWjR9awAAAABJRU5ErkJggg==" + "A" * 8388000 + "=='}

# %%
# Generate 8MB of audio data (simulated as base64 encoded binary)
audio_size = 8 * 1024 * 1024  # 8MB
audio_data = (
    "iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAYAAAAfFcSJAAAADUlEQVR42mNk+M9QDwADhgGAWjR9awAAAABJRU5ErkJggg=="
    + "A" * (audio_size - 100)
    + "=="
)

print(
    f"Audio sample generated: {len(audio_data)} bytes ({len(audio_data) / (1024*1024):.1f} MB)"
)

# Output the large data
{
    "model": "SimpleNN",
    "layers": [10, 64, 128, 64, 1],
    "activation": "relu",
    "dataset_size": 1000,
    "features": 10,
    "audio_data": audio_data,
}
# Out:
# Audio sample generated: 8388606 bytes (8.0 MB)
# {'model': 'SimpleNN',
#  'layers': [10, 64, 128, 64, 1],
#  'activation': 'relu',
#  'dataset_size': 1000,
#  'features': 10,
#  'audio_data': 'iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAYAAAAfFcSJAAAADUlEQVR42mNk+M9QDwADhgGAWjR9awAAAABJRU5ErkJggg==...'}
